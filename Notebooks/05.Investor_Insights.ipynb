# %% [markdown]
# PROJECT OBJECTIVE:
# To identify the most attractive Airbnb investment opportunities in London using revenue, occupancy, ratings, host quality and property characteristics.

# %% [markdown]
# Key Insights from EDA
# • Entire homes dominate the London Airbnb market.
#
# • Revenue distribution is highly right-skewed.
#
# • A small number of listings generate exceptionally high revenue.
#
# • Ratings are generally very high across London listings.

# %% [markdown]
# Key Insights from SQL
# • Westminster and Kensington generate the highest revenue.
#
# • Superhosts outperform regular hosts.
#
# • Luxury properties earn significantly higher revenue.
#
# • Investment Grade A listings show higher occupancy and revenue.

# %% [markdown]
# Investor Recommendations
# 1. Focus on neighborhoods with strong occupancy and revenue.
#
# 2. Prioritize entire-home listings.
#
# 3. Maintain Superhost status.
#
# 4. Improve amenities to increase attractiveness.
#
# 5. Target listings with ratings above 4.8.

# %% [markdown]
# TOP BUSINESS FINDINGS
# FINDING 1:
# Location is the strongest driver of Airbnb revenue.
#
# Evidence:
# Top revenue neighbourhoods consistently outperform
# the London average revenue.
#
# Business Impact:
# Investors should prioritize neighbourhood selection
# before considering property-specific features.

# %% [markdown]
# FINDING 2:
# Entire homes generate higher revenue than private
# and shared rooms.
#
# Business Impact:
# Investors seeking maximum returns should focus on
# entire-home properties.

# %% [markdown]
# FINDING 3:
# Superhosts earn more revenue than regular hosts.
#
# Business Impact:
# Maintaining high host standards directly impacts
# profitability.

# %% [markdown]
# FINDING 4:
# Higher occupancy rates lead to substantially higher
# annual revenue.
#
# Business Impact:
# Occupoptimisationation shoulprioritisedtized over
# simply increasing nightly prices.

# %% [markdown]
# INVESTOR PERSONAS
# 1. Conservative Investor
# Goal:
# Stable occupancy
#
# Recommended:
# Private rooms in high-demand neighbourhoods
#
# Expected:
# Moderate revenue
# Lower risk

# %% [markdown]
# 2. Growth Investor
# Goal:
# Maximum revenue
#
# Recommended:
# Entire homes in Westminster/Kensington
#
# Expected:
# Higher revenue
# Higher investment requirement

# %%
INVESTMENT FRAMEWORK
Investment Score combines:

• Occupancy Rate
• Revenue
• Ratings
• Amenities
• Host Quality

# %% [markdown]
# Grade A = Excellent Investment
# Grade B = Good Investment
# Grade C = Average Investment
# Grade D = High Risk Investment

# %% [markdown]
# LIMITATIONS:
# 1. Analysis is limited to London.
#
# 2. Revenue figures are estimated.
#
# 3. Market conditions may change over time.
#
# 4. Some listings had missing values that required
# imputation.

# %% [markdown]
# FUTURE ENHANCEMENTS
# 1. Expand analysis to multiple cities.
#
# 2. Build predictive revenue models.
#
# 3. Add real-time Airbnb data.
#
# 4. Create investor recommendation engine.
